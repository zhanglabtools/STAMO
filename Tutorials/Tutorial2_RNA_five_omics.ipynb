# %% [markdown]
# # Tutorial 2: five-omics integration

# %% [markdown]
# ### This tutorial demonstrates STAMO’s ablility to integrate five unpaired P22 mouse brain slices: RNA, ATAC, H3K27ac, H3K27me3, and H3K4me3. The raw and processed data can be downloaded from GSE205055 and https://drive.google.com/drive/folders/1_V4IAxblPzNVj6P53PWjVO07lQLn2gIy?usp=sharing, respectively.

# %%
import warnings
warnings.filterwarnings('ignore')

## setting for bedtools calling in jupyter
import os
from os import path
import sys
bin_dir = path.dirname(sys.executable)
os.environ['PATH'] += os.pathsep + bin_dir
# print(os.pathsep + bin_dir)

import pandas as pd
import anndata as ad
import networkx as nx
import scanpy as sc
import STAMO
import numpy as np
import scipy.sparse as sp
from itertools import chain

STAMO.config.BEDTOOLS_PATH = "/mnt/disk4/xzhou/anaconda3/envs/STAMOv1/bin/"

# %% [markdown]
# ## Step 1: Data preprocessing

# %%
datadir = '/mnt/disk2/xzhou/code/pycharm_ATAC/STAMO_v0/data/P22/'

# %%
stH3K27ac = sc.read_h5ad(datadir+'P22_H3K27ac_cuttag.h5ad')
stH3K27me3 = sc.read_h5ad(datadir+'P22_H3K27me3_cuttag.h5ad')
stH3K4me3 = sc.read_h5ad(datadir+'P22_H3K4me3_cuttag.h5ad')
statac = sc.read_h5ad(datadir+'P22_ATAC_atac.h5ad')
strna = sc.read_h5ad(datadir+'P22_H3K27ac_RNA.h5ad')

# %%
strna.layers['counts'] = strna.X.astype(int).copy()
statac.layers['counts'] = statac.X.astype(int).copy()
stH3K4me3.layers['counts'] = stH3K4me3.X.astype(int).copy()
stH3K27me3.layers['counts'] = stH3K27me3.X.astype(int).copy()
stH3K27ac.layers['counts'] = stH3K27ac.X.astype(int).copy()

# %% [markdown]
# ### Preprocess spRNA-seq data

# %%
sc.pp.highly_variable_genes(strna, n_top_genes=5000, flavor="seurat_v3")
sc.pp.normalize_total(strna) #, target_sum=1e4
sc.pp.log1p(strna)
strna = strna[:, strna.var['highly_variable']]
strna.obsm['X_feat'] = strna.X.toarray()

# %% [markdown]
# ### Preprocess spCUT&Tag-seq data

# %%
statac.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(statac.copy(), key='X_lsi')
stH3K27ac.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(stH3K27ac.copy(), key='X_lsi')
stH3K27me3.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(stH3K27me3.copy(), key='X_lsi')
stH3K4me3.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(stH3K4me3.copy(), key='X_lsi')

# %% [markdown]
# ### Prior feature graph construction

# %%
STAMO.data.get_gene_annotation(
    strna, gtf=datadir+"gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz",
    gtf_by="gene_name"
)
strna.var.loc[:, ["chrom", "chromStart", "chromEnd"]].head()

strna = strna[:, ~strna.var['chrom'].isna()]

# %%
strna.var.loc[:, ["chrom", "chromStart", "chromEnd"]].head()
# Out:
#           chrom  chromStart   chromEnd
# Ppp1r14c  chr10   3366056.0  3464975.0
# Plekhg1   chr10   3740363.0  3967303.0
# Mthfd1l   chr10   3973117.0  4167081.0
# Ccdc170   chr10   4482501.0  4562231.0
# Gm10097   chr10   5069191.0  5071975.0

# %%
split = stH3K27ac.var_names.str.split(r"[:-]")
stH3K27ac.var["chrom"] = split.map(lambda x: x[0])
stH3K27ac.var["chromStart"] = split.map(lambda x: x[1]).astype(int)
stH3K27ac.var["chromEnd"] = split.map(lambda x: x[2]).astype(int)
stH3K27ac.var.head()
# Out:
#                      chrom  chromStart  chromEnd
# chr1-3094679-3094964  chr1     3094679   3094964
# chr1-3119499-3119936  chr1     3119499   3119936
# chr1-3121345-3121681  chr1     3121345   3121681
# chr1-3250538-3251680  chr1     3250538   3251680
# chr1-3263733-3264531  chr1     3263733   3264531

# %%
split = statac.var_names.str.split(r"[:-]")
statac.var["chrom"] = split.map(lambda x: x[0])
statac.var["chromStart"] = split.map(lambda x: x[1]).astype(int)
statac.var["chromEnd"] = split.map(lambda x: x[2]).astype(int)
statac.var.head()
# Out:
#                      chrom  chromStart  chromEnd
# chr1-3094750-3095365  chr1     3094750   3095365
# chr1-3119542-3120773  chr1     3119542   3120773
# chr1-3121337-3121583  chr1     3121337   3121583
# chr1-3210558-3211041  chr1     3210558   3211041
# chr1-3217182-3217395  chr1     3217182   3217395

# %%
split = stH3K27me3.var_names.str.split(r"[:-]")
stH3K27me3.var["chrom"] = split.map(lambda x: x[0])
stH3K27me3.var["chromStart"] = split.map(lambda x: x[1]).astype(int)
stH3K27me3.var["chromEnd"] = split.map(lambda x: x[2]).astype(int)
stH3K27me3.var.head()
# Out:
#                      chrom  chromStart  chromEnd  highly_variable
# chr1-3003174-3003765  chr1     3003174   3003765            False
# chr1-3670444-3672519  chr1     3670444   3672519            False
# chr1-3756434-3757164  chr1     3756434   3757164            False
# chr1-3915513-3915977  chr1     3915513   3915977            False
# chr1-4038897-4039205  chr1     4038897   4039205             True

# %%
split = stH3K4me3.var_names.str.split(r"[:-]")
stH3K4me3.var["chrom"] = split.map(lambda x: x[0])
stH3K4me3.var["chromStart"] = split.map(lambda x: x[1]).astype(int)
stH3K4me3.var["chromEnd"] = split.map(lambda x: x[2]).astype(int)
stH3K4me3.var.head()
# Out:
#                      chrom  chromStart  chromEnd
# chr1-3433875-3434074  chr1     3433875   3434074
# chr1-3670113-3672402  chr1     3670113   3672402
# chr1-4471407-4471612  chr1     4471407   4471612
# chr1-4491703-4493730  chr1     4491703   4493730
# chr1-4496203-4496619  chr1     4496203   4496619

# %%
guidance_atac = STAMO.genomics.rna_anchored_guidance_graph(strna, statac, propagate_highly_variable = True) 
guidance_H3K4me3 = STAMO.genomics.rna_anchored_guidance_graph(strna, stH3K4me3, propagate_highly_variable = True)
guidance_H3K27ac = STAMO.genomics.rna_anchored_guidance_graph(strna, stH3K27ac, propagate_highly_variable = True)
guidance_H3K27me3 = STAMO.genomics.rna_anchored_guidance_graph(strna, stH3K27me3, propagate_highly_variable = True, signs=[-1])  # negative for H3K27me3

graph_tri = STAMO.graph.compose_multigraph(guidance_atac, guidance_H3K4me3, guidance_H3K27ac, guidance_H3K27me3)
len(graph_tri)
# Out:
# window_graph: 100%|██████████| 4527/4527 [00:00<00:00, 4861.66it/s]
# window_graph: 100%|██████████| 4527/4527 [00:00<00:00, 18460.03it/s]
# window_graph: 100%|██████████| 4527/4527 [00:00<00:00, 6176.19it/s]
# window_graph: 100%|██████████| 4527/4527 [00:00<00:00, 6785.35it/s]
# 441202

# %%
STAMO.graph.check_graph(graph_tri, [strna, statac, stH3K4me3, stH3K27ac, stH3K27me3])
# Out:
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] check_graph: All checks passed!

# %%
strna.var['highly_variable'].sum()
# Out:
# 4527

# %%
nx.write_graphml(graph_tri, datadir+"P22_five_omics_guidance.graphml.gz")

strna.write(datadir+"P22_five_omics_RNA_pp.h5ad", compression="gzip")
statac.write(datadir+"P22_five_omics_ATAC_pp.h5ad", compression="gzip")
stH3K27ac.write(datadir+"P22_five_omics_H3K27ac_pp.h5ad", compression="gzip")
stH3K4me3.write(datadir+"P22_five_omics_H3K4me3_pp.h5ad", compression="gzip")
stH3K27me3.write(datadir+"P22_five_omics_H3K27me3_pp.h5ad", compression="gzip")

# %% [markdown]
# ## Step 2: Model training

# %%
strna = ad.read_h5ad(datadir+"P22_five_omics_RNA_pp.h5ad")
statac = ad.read_h5ad(datadir+"P22_five_omics_ATAC_pp.h5ad")
stH3K27ac = ad.read_h5ad(datadir+"P22_five_omics_H3K27ac_pp.h5ad")
stH3K4me3 = ad.read_h5ad(datadir+"P22_five_omics_H3K4me3_pp.h5ad")
stH3K27me3 = ad.read_h5ad(datadir+"P22_five_omics_H3K27me3_pp.h5ad")
guidance = nx.read_graphml(datadir+"P22_five_omics_guidance.graphml.gz")

strna.X = sp.csr_matrix(strna.X)
statac.X = sp.csr_matrix(statac.X)
stH3K27ac.X = sp.csr_matrix(stH3K27ac.X)
stH3K4me3.X = sp.csr_matrix(stH3K4me3.X)
stH3K27me3.X = sp.csr_matrix(stH3K27me3.X)

strna.obs_names = strna.obs_names+'_rna'
statac.obs_names = statac.obs_names+'_atac'
stH3K27ac.obs_names = stH3K27ac.obs_names+'_H3K27ac'
stH3K4me3.obs_names = stH3K4me3.obs_names+'_H3K4me3'
stH3K27me3.obs_names = stH3K27me3.obs_names+'_H3K27me3'

# %%
# Constructing the spatial neighbor network
STAMO.utils.Cal_Spatial_Net(strna, rad_cutoff=1.3)  # the spatial network are saved in adata.uns[‘adj’]
STAMO.utils.Cal_Spatial_Net(statac, rad_cutoff=1.3)
STAMO.utils.Cal_Spatial_Net(stH3K27ac, rad_cutoff=1.3)
STAMO.utils.Cal_Spatial_Net(stH3K4me3, rad_cutoff=1.3)
STAMO.utils.Cal_Spatial_Net(stH3K27me3, rad_cutoff=1.3)
# STAMO.utils.Stats_Spatial_Net(statac)
# Out:
# ------Calculating spatial graph...
# The graph contains 37084 edges, 9370 cells.
# 3.9577 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 36464 edges, 9215 cells.
# 3.9570 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 37084 edges, 9370 cells.
# 3.9577 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 37796 edges, 9548 cells.
# 3.9585 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 38612 edges, 9752 cells.
# 3.9594 neighbors per cell on average.

# %%
## only highly_variable features are used
guidance_hvf = guidance.subgraph(chain(
    strna.var.query("highly_variable").index,
    # statac.var.index
    statac.var.query("highly_variable").index,
    stH3K27ac.var.query("highly_variable").index,
    stH3K4me3.var.query("highly_variable").index,
    stH3K27me3.var.query("highly_variable").index,
)).copy()

vertices = sorted(guidance_hvf.nodes)

# %%
## Dataset configure
STAMO.models.configure_dataset(strna, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_feat", use_obs_names=True)
STAMO.models.configure_dataset(statac, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_lsi", use_obs_names=True)
STAMO.models.configure_dataset(stH3K27ac, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_lsi", use_obs_names=True)
STAMO.models.configure_dataset(stH3K4me3, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_lsi", use_obs_names=True)
STAMO.models.configure_dataset(stH3K27me3, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_lsi", use_obs_names=True)

# %%
model = STAMO.models.train(
    {"RNA": strna, "ATAC": statac, "H3K27ac": stH3K27ac, "H3K4me3": stH3K4me3, "H3K27me3": stH3K27me3}, guidance_hvf,
    fit_kws={"directory": "outputs/P22_five_omics"}, OT_pair=[('RNA','ATAC'),('RNA','H3K27ac'),('RNA','H3K4me3'),('RNA','H3K27me3')]  
    ### compile_kws={"lam_align": 0.05}
)
# Out:
# [INFO] autodevice: Using GPU 3 as computation device.
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] STAMOModel: Setting `graph_batch_size` = 79214
# [INFO] STAMOModel: Setting `max_epochs` = 73
# [INFO] STAMOModel: Setting `patience` = 7
# [INFO] STAMOModel: Setting `reduce_lr_patience` = 4
# [INFO] STAMOTrainer: Using training directory: "outputs/P22_five_omics/pretrain"
# [INFO] STAMOTrainer: [Epoch 10] train={'g_nll': 0.413, 'g_kl': 0.002, 'g_elbo': 0.415, 'x_RNA_nll': 0.264, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.267, 'x_ATAC_nll': 0.118, 'x_ATAC_kl': 0.001, 'x_ATAC_elbo': 0.119, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'x_H3K4me3_nll': 0.176, 'x_H3K4me3_kl': 0.002, 'x_H3K4me3_elbo': 0.178, 'x_H3K27me3_nll': 0.074, 'x_H3K27me3_kl': 0.001, 'x_H3K27me3_elbo': 0.075, 'dsc_loss': 1.607, 'vae_loss': 0.781, 'gen_loss': 0.701, 'cos_loss': 0.0, 'gate_rec_loss': 8.262}, val=None, 72.4s elapsed
# [INFO] STAMOTrainer: [Epoch 20] train={'g_nll': 0.401, 'g_kl': 0.002, 'g_elbo': 0.403, 'x_RNA_nll': 0.262, 'x_RNA_kl': 0.003, 'x_RNA_elbo': 0.265, 'x_ATAC_nll': 0.118, 'x_ATAC_kl': 0.001, 'x_ATAC_elbo': 0.119, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'x_H3K4me3_nll': 0.176, 'x_H3K4me3_kl': 0.002, 'x_H3K4me3_elbo': 0.178, 'x_H3K27me3_nll': 0.074, 'x_H3K27me3_kl': 0.001, 'x_H3K27me3_elbo': 0.075, 'dsc_loss': 1.609, 'vae_loss': 0.776, 'gen_loss': 0.696, 'cos_loss': 0.0, 'gate_rec_loss': 7.939}, val=None, 77.9s elapsed
# [INFO] STAMOTrainer: [Epoch 30] train={'g_nll': 0.399, 'g_kl': 0.002, 'g_elbo': 0.402, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.003, 'x_RNA_elbo': 0.263, 'x_ATAC_nll': 0.117, 'x_ATAC_kl': 0.001, 'x_ATAC_elbo': 0.118, 'x_H3K27ac_nll': 0.09, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'x_H3K4me3_nll': 0.175, 'x_H3K4me3_kl': 0.002, 'x_H3K4me3_elbo': 0.177, 'x_H3K27me3_nll': 0.073, 'x_H3K27me3_kl': 0.001, 'x_H3K27me3_elbo': 0.074, 'dsc_loss': 1.609, 'vae_loss': 0.772, 'gen_loss': 0.692, 'cos_loss': 0.0, 'gate_rec_loss': 7.986}, val=None, 76.2s elapsed
# [INFO] STAMOTrainer: [Epoch 40] train={'g_nll': 0.4, 'g_kl': 0.002, 'g_elbo': 0.402, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.003, 'x_RNA_elbo': 0.264, 'x_ATAC_nll': 0.117, 'x_ATAC_kl': 0.001, 'x_ATAC_elbo': 0.118, 'x_H3K27ac_nll': 0.09, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'x_H3K4me3_nll': 0.175, 'x_H3K4me3_kl': 0.002, 'x_H3K4me3_elbo': 0.177, 'x_H3K27me3_nll': 0.073, 'x_H3K27me3_kl': 0.001, 'x_H3K27me3_elbo': 0.074, 'dsc_loss': 1.609, 'vae_loss': 0.772, 'gen_loss': 0.692, 'cos_loss': 0.0, 'gate_rec_loss': 7.982}, val=None, 72.2s elapsed
# Epoch 00042: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00042: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] STAMOTrainer: [Epoch 50] train={'g_nll': 0.399, 'g_kl': 0.002, 'g_elbo': 0.401, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.003, 'x_RNA_elbo': 0.263, 'x_ATAC_nll': 0.116, 'x_ATAC_kl': 0.001, 'x_ATAC_elbo': 0.117, 'x_H3K27ac_nll': 0.09, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'x_H3K4me3_nll': 0.175, 'x_H3K4me3_kl': 0.002, 'x_H3K4me3_elbo': 0.177, 'x_H3K27me3_nll': 0.073, 'x_H3K27me3_kl': 0.001, 'x_H3K27me3_elbo': 0.074, 'dsc_loss': 1.608, 'vae_loss': 0.772, 'gen_loss': 0.691, 'cos_loss': 0.0, 'gate_rec_loss': 7.967}, val=None, 73.2s elapsed
# Epoch 00051: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00051: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# 2025-06-28 11:23:28,564 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "46"...
# [INFO] EarlyStopping: Restoring checkpoint "46"...
# [INFO] train: FGW OT mapping from source RNA to ATAC
# [INFO] train: downsample source data to 5000...
# [INFO] train: downsample target data to 5000...
# How many source profiles were paired to an destination profile of the same cluster type: 0.9258
# [INFO] train: FGW OT mapping from source RNA to H3K27ac
# [INFO] train: downsample source data to 5000...
# [INFO] train: downsample target data to 5000...
# How many source profiles were paired to an destination profile of the same cluster type: 0.938
# [INFO] train: FGW OT mapping from source RNA to H3K4me3
# [INFO] train: downsample source data to 5000...
# [INFO] train: downsample target data to 5000...
# How many source profiles were paired to an destination profile of the same cluster type: 0.8928
# [INFO] train: FGW OT mapping from source RNA to H3K27me3
# [INFO] train: downsample source data to 5000...
# [INFO] train: downsample target data to 5000...
# How many source profiles were paired to an destination profile of the same cluster type: 0.9226
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] STAMOModel: Setting `graph_batch_size` = 79214
# [INFO] STAMOModel: Setting `align_burnin` = 14
# [INFO] STAMOModel: Setting `max_epochs` = 84
# [INFO] STAMOModel: Setting `patience` = 7
# [INFO] STAMOModel: Setting `reduce_lr_patience` = 4
# [INFO] STAMOTrainer: Using training directory: "outputs/P22_five_omics/fine-tune"
# [INFO] STAMOTrainer: [Epoch 10] train={'g_nll': 0.398, 'g_kl': 0.002, 'g_elbo': 0.4, 'x_RNA_nll': 0.261, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.265, 'x_ATAC_nll': 0.117, 'x_ATAC_kl': 0.001, 'x_ATAC_elbo': 0.118, 'x_H3K27ac_nll': 0.09, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.091, 'x_H3K4me3_nll': 0.174, 'x_H3K4me3_kl': 0.002, 'x_H3K4me3_elbo': 0.176, 'x_H3K27me3_nll': 0.073, 'x_H3K27me3_kl': 0.001, 'x_H3K27me3_elbo': 0.074, 'dsc_loss': 1.604, 'vae_loss': 0.779, 'gen_loss': 0.699, 'cos_loss': 0.302, 'gate_rec_loss': 7.911}, val=None, 62.7s elapsed
# [INFO] STAMOTrainer: [Epoch 20] train={'g_nll': 0.397, 'g_kl': 0.002, 'g_elbo': 0.399, 'x_RNA_nll': 0.262, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.266, 'x_ATAC_nll': 0.117, 'x_ATAC_kl': 0.001, 'x_ATAC_elbo': 0.118, 'x_H3K27ac_nll': 0.09, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'x_H3K4me3_nll': 0.175, 'x_H3K4me3_kl': 0.002, 'x_H3K4me3_elbo': 0.177, 'x_H3K27me3_nll': 0.073, 'x_H3K27me3_kl': 0.001, 'x_H3K27me3_elbo': 0.075, 'dsc_loss': 1.597, 'vae_loss': 0.781, 'gen_loss': 0.701, 'cos_loss': 0.287, 'gate_rec_loss': 7.837}, val=None, 62.1s elapsed
# Epoch 00022: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00022: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# Epoch 00027: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00027: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] STAMOTrainer: [Epoch 30] train={'g_nll': 0.396, 'g_kl': 0.002, 'g_elbo': 0.398, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.264, 'x_ATAC_nll': 0.117, 'x_ATAC_kl': 0.001, 'x_ATAC_elbo': 0.118, 'x_H3K27ac_nll': 0.09, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'x_H3K4me3_nll': 0.175, 'x_H3K4me3_kl': 0.002, 'x_H3K4me3_elbo': 0.177, 'x_H3K27me3_nll': 0.073, 'x_H3K27me3_kl': 0.001, 'x_H3K27me3_elbo': 0.074, 'dsc_loss': 1.6, 'vae_loss': 0.777, 'gen_loss': 0.697, 'cos_loss': 0.272, 'gate_rec_loss': 7.892}, val=None, 63.0s elapsed
# Epoch 00032: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00032: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# 2025-06-28 12:06:58,262 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "28"...
# [INFO] EarlyStopping: Restoring checkpoint "28"...

# %%
strna.obsm["X_STAMO"] = model.encode_data_minibatch("RNA", strna)
statac.obsm["X_STAMO"] = model.encode_data_minibatch("ATAC", statac)
stH3K27ac.obsm["X_STAMO"] = model.encode_data_minibatch("H3K27ac", stH3K27ac)
stH3K4me3.obsm["X_STAMO"] = model.encode_data_minibatch("H3K4me3", stH3K4me3)
stH3K27me3.obsm["X_STAMO"] = model.encode_data_minibatch("H3K27me3", stH3K27me3)

combined = ad.concat([strna, statac, stH3K27ac, stH3K4me3, stH3K27me3], label='Batch', keys=['RNA', 'ATAC', "H3K27ac", "H3K4me3", 'H3K27me3'],join='outer')
sc.pp.neighbors(combined, use_rep="X_STAMO", metric="cosine")
sc.tl.umap(combined)

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams["figure.figsize"] = (2, 2)
plt.rcParams['font.size'] = 10
plt.rcParams['legend.handletextpad'] = 0.01 
fig, ax = plt.subplots(1, 2, figsize=(10, 3), gridspec_kw={'wspace': 0.8, 'hspace': 0.1})

sc.pl.umap(combined, color=["Batch"], wspace=1, show=False, ax=ax[0])
sc.pl.umap(combined, color=['annotation'], legend_fontsize=10, show=False, ax=ax[1])   #, legend_loc=None
plt.show()

# %%
sc.tl.leiden(combined, random_state=666, key_added="leiden", resolution=1.4) 

strna.obs['leiden'] = combined.obs['leiden'][combined.obs['Batch']=='RNA'].values
statac.obs['leiden'] = combined.obs['leiden'][combined.obs['Batch']=='ATAC'].values
stH3K27ac.obs['leiden'] = combined.obs['leiden'][combined.obs['Batch']=='H3K27ac'].values
stH3K4me3.obs['leiden'] = combined.obs['leiden'][combined.obs['Batch']=='H3K4me3'].values
stH3K27me3.obs['leiden'] = combined.obs['leiden'][combined.obs['Batch']=='H3K27me3'].values

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams["figure.figsize"] = (3, 3)
plt.rcParams['font.size'] = 10
plt.rcParams['legend.handletextpad'] = 0.01
# plt.rcParams['legend.labelspacing'] = 0.1 

spot_size = 30
fig, ax = plt.subplots(1, 5, figsize=(15, 3), gridspec_kw={'wspace': 0.2, 'hspace': 0.1})

spot_size = 1.1 
sc.pl.spatial(strna, color='leiden', cmap="viridis", show=False, frameon=False, spot_size=spot_size, title=['RNA'], ax=ax[0], legend_loc=None)
sc.pl.spatial(statac, color='leiden', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title=['ATAC'], ax=ax[1], legend_loc=None)
sc.pl.spatial(stH3K27ac, color='leiden', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title=['H3K27ac'], ax=ax[2], legend_loc=None)
sc.pl.spatial(stH3K27me3, color='leiden', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title=['H3K27me3'], ax=ax[3], legend_loc=None)
sc.pl.spatial(stH3K4me3, color='leiden', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title=['H3K4me3'], ax=ax[4])
plt.show()
