# %% [markdown]
# # Tutorial 3: Integration of mouse embryo brain slices across different developmental stages

# %% [markdown]
# This tutorial demonstrates STAMO’s ablility in cross-omics and cross-batch integration. The raw and processed data can be downloaded from the National Genomics Data Center with accession number OEP003285 and https://drive.google.com/drive/folders/1tUOEDGBrlFBsZZ0ag_pQcO_j6uELeZRk?usp=sharing, respectively.

# %%
import warnings
warnings.filterwarnings('ignore')

## setting for bedtools calling in jupyter
import os
from os import path
import sys
bin_dir = path.dirname(sys.executable)
os.environ['PATH'] += os.pathsep + bin_dir
# print(os.pathsep + bin_dir)

import pandas as pd
import anndata as ad
import networkx as nx
import scanpy as sc
import STAMO
import numpy as np
import scipy.sparse as sp
from itertools import chain

STAMO.config.BEDTOOLS_PATH = "/mnt/disk4/xzhou/anaconda3/envs/STAMOv1/bin/"

# %% [markdown]
# ## Step 1: Data preprocessing

# %%
datadir = '/mnt/disk2/xzhou/code/pycharm_ATAC/STAMO_v0/data/MISAR-seq/'

strna_e11 = ad.read_h5ad(datadir+"E11_0_RNA_raw.h5ad")
statac_e11 = ad.read_h5ad(datadir+"E11_0_ATAC_raw.h5ad")

strna_e13 = ad.read_h5ad(datadir+"E13_5_RNA_raw.h5ad")
statac_e13 = ad.read_h5ad(datadir+"E13_5_ATAC_raw.h5ad")

strna_e15 = ad.read_h5ad(datadir+"E15_5_RNA_raw.h5ad")
statac_e15 = ad.read_h5ad(datadir+"E15_5_ATAC_raw.h5ad")

strna_e18 = ad.read_h5ad(datadir+"E18_5_RNA_raw.h5ad")
statac_e18 = ad.read_h5ad(datadir+"E18_5_ATAC_raw.h5ad")

# %%
statac = sc.read_h5ad(datadir+"ATAC_four_stages_combined.h5ad")
statac
# Out:
# AnnData object with n_obs × n_vars = 7118 × 191034
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'Combined_Clusters_annotation', 'ATAC_Clusters', 'RNA_Clusters', 'Combined_Clusters', 'Sample_name', 'array_col', 'array_row', 'Batch', 'annotation'
#     obsm: 'X_lsi', 'spatial'

# %%
sc.pp.highly_variable_genes(strna_e11, n_top_genes=15000, flavor="seurat_v3")
sc.pp.highly_variable_genes(strna_e13, n_top_genes=15000, flavor="seurat_v3")
sc.pp.highly_variable_genes(strna_e15, n_top_genes=15000, flavor="seurat_v3")
sc.pp.highly_variable_genes(strna_e18, n_top_genes=15000, flavor="seurat_v3")

strna = ad.concat([strna_e11[:, strna_e11.var['highly_variable']], strna_e13[:, strna_e13.var['highly_variable']], 
                   strna_e15[:, strna_e15.var['highly_variable']], strna_e18[:, strna_e18.var['highly_variable']]], 
                   label="Batch", keys=['rna_e11', 'rna_e13', 'rna_e15', 'rna_e18'])
strna.var['highly_variable'] = True
print(strna.shape)
# Out:
# (7118, 2537)

# %%
statac_e18
# Out:
# AnnData object with n_obs × n_vars = 2129 × 117473
#     obs: 'ATAC_Clusters', 'RNA_Clusters', 'Combined_Clusters', 'Combined_Clusters_annotation', 'my_annotation', 'annotation'
#     var: 'features'
#     uns: 'annotation_colors'
#     obsm: 'X_lsi', 'X_lsi_new', 'spatial'

# %%
statac.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(statac, n_peak=100000, key='X_lsi')

# statac_e11.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(statac_e11, key='X_lsi')
# statac_e13.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(statac_e13, key='X_lsi')
# statac_e15.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(statac_e15, key='X_lsi')
# statac_e18.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(statac_e18, key='X_lsi')

# %%
STAMO.data.get_gene_annotation(
    strna, gtf=datadir+"gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz",
    gtf_by="gene_name"
)

strna = strna[:, ~strna.var['chrom'].isna()]

# %%
strna.var.loc[:, ["chrom", "chromStart", "chromEnd"]].head()
# Out:
#               chrom  chromStart    chromEnd
# features
# Rgs20          chr1   4909575.0   5070285.0
# 4732440D04Rik  chr1   6209865.0   6215293.0
# St18           chr1   6487230.0   6860940.0
# Mybl1          chr1   9667414.0   9700209.0
# Prex2          chr1  10993464.0  11303681.0

# %%
split = statac.var_names.str.split(r"[:-]")
statac.var["chrom"] = split.map(lambda x: x[0])
statac.var["chromStart"] = split.map(lambda x: x[1]).astype(int)
statac.var["chromEnd"] = split.map(lambda x: x[2]).astype(int)
statac.var.head()
# Out:
#                      chrom  chromStart  chromEnd
# features
# chr1-3094803-3095303  chr1     3094803   3095303
# chr1-3113543-3114043  chr1     3113543   3114043
# chr1-3120248-3120748  chr1     3120248   3120748
# chr1-3325117-3325617  chr1     3325117   3325617
# chr1-3399906-3400406  chr1     3399906   3400406

# %%
guidance = STAMO.genomics.rna_anchored_guidance_graph(strna, statac, propagate_highly_variable = True)
guidance
# Out:
# window_graph: 100%|██████████| 2512/2512 [00:01<00:00, 2190.98it/s]

# %%
STAMO.graph.check_graph(guidance, [strna, statac])
# Out:
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] check_graph: All checks passed!

# %%
statac.var['highly_variable'].sum()
# Out:
# 14786

# %%
strna.var['highly_variable'].sum()
# Out:
# 2512

# %%
statac1 = statac[statac.obs['Batch'] == 'atac_e11']
statac2 = statac[statac.obs['Batch'] == 'atac_e13']
statac3 = statac[statac.obs['Batch'] == 'atac_e15']
statac4 = statac[statac.obs['Batch'] == 'atac_e18']

statac1.obsm['X_lsi'] = statac_e11.obsm['X_lsi']
statac2.obsm['X_lsi'] = statac_e13.obsm['X_lsi']
statac3.obsm['X_lsi'] = statac_e15.obsm['X_lsi']
statac4.obsm['X_lsi'] = statac_e18.obsm['X_lsi']

statac1.obs['annotation'] = statac_e11[statac1.obs_names].obs['annotation'].values
statac2.obs['annotation'] = statac_e13[statac2.obs_names].obs['annotation'].values
statac3.obs['annotation'] = statac_e15[statac3.obs_names].obs['annotation'].values
statac4.obs['annotation'] = statac_e18[statac4.obs_names].obs['annotation'].values

# %%
statac_e11.shape, statac_e13.shape, statac_e15.shape, statac_e18.shape
# Out:
# ((1263, 69370), (1777, 123840), (1949, 141420), (2129, 117473))

# %%
strna1 = strna[strna.obs['Batch'] == 'rna_e11']
strna2 = strna[strna.obs['Batch'] == 'rna_e13']
strna3 = strna[strna.obs['Batch'] == 'rna_e15']
strna4 = strna[strna.obs['Batch'] == 'rna_e18']

# %%
strna1.write_h5ad(datadir + 'E11_0_RNA_pp.h5ad')
strna2.write_h5ad(datadir + 'E13_5_RNA_pp.h5ad')
strna3.write_h5ad(datadir + 'E15_5_RNA_pp.h5ad')
strna4.write_h5ad(datadir + 'E18_5_RNA_pp.h5ad')

statac1.write_h5ad(datadir + 'E11_0_ATAC_pp.h5ad')
statac2.write_h5ad(datadir + 'E13_5_ATAC_pp.h5ad')
statac3.write_h5ad(datadir + 'E15_5_ATAC_pp.h5ad')
statac4.write_h5ad(datadir + 'E18_5_ATAC_pp.h5ad')

nx.write_graphml(guidance, datadir+"mouse_embryo_guidance.graphml.gz")

# %% [markdown]
# ## Step 2: Model training

# %%
strna_e11 = ad.read_h5ad(datadir+"E11_0_RNA_pp.h5ad")
statac_e11 = ad.read_h5ad(datadir+"E11_0_ATAC_pp.h5ad")

strna_e13 = ad.read_h5ad(datadir+"E13_5_RNA_pp.h5ad")
statac_e13 = ad.read_h5ad(datadir+"E13_5_ATAC_pp.h5ad")

strna_e15 = ad.read_h5ad(datadir+"E15_5_RNA_pp.h5ad")
statac_e15 = ad.read_h5ad(datadir+"E15_5_ATAC_pp.h5ad")

strna_e18 = ad.read_h5ad(datadir+"E18_5_RNA_pp.h5ad")
statac_e18 = ad.read_h5ad(datadir+"E18_5_ATAC_pp.h5ad")

guidance = nx.read_graphml(datadir+"mouse_embryo_guidance.graphml.gz")

# %%
strna_e11.obs_names = strna_e11.obs_names+'_rna_E11'
statac_e11.obs_names = statac_e11.obs_names+'_atac_E11'
strna_e13.obs_names = strna_e13.obs_names+'_rna_E13'
statac_e13.obs_names = statac_e13.obs_names+'_atac_E13'
strna_e15.obs_names = strna_e15.obs_names+'_rna_E15'
statac_e15.obs_names = statac_e15.obs_names+'_atac_E15'
strna_e18.obs_names = strna_e18.obs_names+'_rna_E18'
statac_e18.obs_names = statac_e18.obs_names+'_atac_E18'

# %%
statac_e11.layers['counts'] = statac_e11.X.copy().astype(int)
statac_e13.layers['counts'] = statac_e13.X.copy().astype(int)
statac_e15.layers['counts'] = statac_e15.X.copy().astype(int)
statac_e18.layers['counts'] = statac_e18.X.copy().astype(int)

# %%
strna_e11.layers['counts'] = strna_e11.X.copy().astype(int)
sc.pp.normalize_total(strna_e11) #, target_sum=1e4
sc.pp.log1p(strna_e11)
strna_e11 = strna_e11[:, strna_e11.var['highly_variable']]
strna_e11.obsm['X_feat'] = strna_e11.X.toarray()

strna_e13.layers['counts'] = strna_e13.X.copy().astype(int)
sc.pp.normalize_total(strna_e13) #, target_sum=1e4
sc.pp.log1p(strna_e13)
strna_e13 = strna_e13[:, strna_e13.var['highly_variable']]
strna_e13.obsm['X_feat'] = strna_e13.X.toarray()

strna_e15.layers['counts'] = strna_e15.X.copy().astype(int)
sc.pp.normalize_total(strna_e15) #, target_sum=1e4
sc.pp.log1p(strna_e15)
strna_e15 = strna_e15[:, strna_e15.var['highly_variable']]
strna_e15.obsm['X_feat'] = strna_e15.X.toarray()

strna_e18.layers['counts'] = strna_e18.X.copy().astype(int)
sc.pp.normalize_total(strna_e18) #, target_sum=1e4
sc.pp.log1p(strna_e18)
strna_e18 = strna_e18[:, strna_e18.var['highly_variable']]
strna_e18.obsm['X_feat'] = strna_e18.X.toarray()

# %%
STAMO.utils.Cal_Spatial_Net(strna_e11, rad_cutoff=1.3)  # the spatial network are saved in adata.uns[‘adj’]
STAMO.utils.Cal_Spatial_Net(statac_e11, rad_cutoff=1.3)

STAMO.utils.Cal_Spatial_Net(strna_e13, rad_cutoff=1.3)  # the spatial network are saved in adata.uns[‘adj’]
STAMO.utils.Cal_Spatial_Net(statac_e13, rad_cutoff=1.3)

STAMO.utils.Cal_Spatial_Net(strna_e15, rad_cutoff=1.3)  # the spatial network are saved in adata.uns[‘adj’]
STAMO.utils.Cal_Spatial_Net(statac_e15, rad_cutoff=1.3)

STAMO.utils.Cal_Spatial_Net(strna_e18, rad_cutoff=1.3)  # the spatial network are saved in adata.uns[‘adj’]
STAMO.utils.Cal_Spatial_Net(statac_e18, rad_cutoff=1.3)
# Out:
# ------Calculating spatial graph...
# The graph contains 4718 edges, 1263 cells.
# 3.7356 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 4718 edges, 1263 cells.
# 3.7356 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 6808 edges, 1777 cells.
# 3.8312 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 6808 edges, 1777 cells.
# 3.8312 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 7450 edges, 1949 cells.
# 3.8225 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 7450 edges, 1949 cells.
# 3.8225 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 8316 edges, 2129 cells.
# 3.9061 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 8316 edges, 2129 cells.
# 3.9061 neighbors per cell on average.

# %%
guidance_hvf = guidance.subgraph(chain(
    strna_e11.var.query("highly_variable").index,
    strna_e13.var.query("highly_variable").index,
    strna_e15.var.query("highly_variable").index,
    strna_e18.var.query("highly_variable").index,
    
    statac_e11.var.query("highly_variable").index,
    statac_e13.var.query("highly_variable").index,
    statac_e15.var.query("highly_variable").index,
    statac_e18.var.query("highly_variable").index
)).copy()
vertices = sorted(guidance_hvf.nodes)

# %%
STAMO.models.configure_dataset(strna_e11, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_feat", use_obs_names=True)
STAMO.models.configure_dataset(strna_e13, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_feat", use_obs_names=True)
STAMO.models.configure_dataset(strna_e15, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_feat", use_obs_names=True)
STAMO.models.configure_dataset(strna_e18, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_feat", use_obs_names=True)

STAMO.models.configure_dataset(statac_e11, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_lsi", use_obs_names=True)
STAMO.models.configure_dataset(statac_e13, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_lsi", use_obs_names=True)
STAMO.models.configure_dataset(statac_e15, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_lsi", use_obs_names=True)
STAMO.models.configure_dataset(statac_e18, "NB", use_highly_variable=True, use_layer="counts", use_rep="X_lsi", use_obs_names=True)

# %%
model = STAMO.models.train(
    {"rna1": strna_e11,"rna2": strna_e13, "rna3": strna_e15,"rna4": strna_e18,
     "atac1": statac_e11, "atac2": statac_e13, "atac3": statac_e15, "atac4": statac_e18}, guidance_hvf,
    fit_kws={"directory": "outputs/Mouse_embryo"}, 
    OT_pair=[('rna1','atac1'),('rna2','atac2'),('rna3','atac3'),('rna4','atac4')]
    ### compile_kws={"lam_align": 0.05}
)
# Out:
# [INFO] autodevice: Using GPU 3 as computation device.
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] STAMOModel: Setting `graph_batch_size` = 16276
# [INFO] STAMOModel: Setting `max_epochs` = 240
# [INFO] STAMOModel: Setting `patience` = 20
# [INFO] STAMOModel: Setting `reduce_lr_patience` = 10
# [INFO] STAMOTrainer: Using training directory: "outputs/Mouse_embryo/pretrain"
# [INFO] STAMOTrainer: [Epoch 10] train={'g_nll': 0.511, 'g_kl': 0.01, 'g_elbo': 0.52, 'x_rna1_nll': 0.206, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.21, 'x_rna2_nll': 0.257, 'x_rna2_kl': 0.005, 'x_rna2_elbo': 0.262, 'x_rna3_nll': 0.302, 'x_rna3_kl': 0.006, 'x_rna3_elbo': 0.308, 'x_rna4_nll': 0.211, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.215, 'x_atac1_nll': 0.136, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.138, 'x_atac2_nll': 0.145, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.198, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.199, 'x_atac4_nll': 0.17, 'x_atac4_kl': 0.002, 'x_atac4_elbo': 0.172, 'dsc_loss': 2.033, 'vae_loss': 1.76, 'gen_loss': 1.658, 'cos_loss': 0.0, 'gate_rec_loss': 27.023}, val=None, 25.6s elapsed
# [INFO] STAMOTrainer: [Epoch 20] train={'g_nll': 0.472, 'g_kl': 0.01, 'g_elbo': 0.482, 'x_rna1_nll': 0.201, 'x_rna1_kl': 0.004, 'x_rna1_elbo': 0.206, 'x_rna2_nll': 0.253, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.257, 'x_rna3_nll': 0.295, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.3, 'x_rna4_nll': 0.208, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.212, 'x_atac1_nll': 0.136, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.137, 'x_atac2_nll': 0.145, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.196, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.198, 'x_atac4_nll': 0.169, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.17, 'dsc_loss': 2.061, 'vae_loss': 1.723, 'gen_loss': 1.62, 'cos_loss': 0.0, 'gate_rec_loss': 20.993}, val=None, 25.3s elapsed
# [INFO] STAMOTrainer: [Epoch 30] train={'g_nll': 0.45, 'g_kl': 0.009, 'g_elbo': 0.459, 'x_rna1_nll': 0.2, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.205, 'x_rna2_nll': 0.251, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.255, 'x_rna3_nll': 0.293, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.298, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.21, 'x_atac1_nll': 0.135, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.136, 'x_atac2_nll': 0.143, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.144, 'x_atac3_nll': 0.195, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.197, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.002, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.062, 'vae_loss': 1.707, 'gen_loss': 1.604, 'cos_loss': 0.0, 'gate_rec_loss': 18.628}, val=None, 25.5s elapsed
# [INFO] STAMOTrainer: [Epoch 40] train={'g_nll': 0.437, 'g_kl': 0.009, 'g_elbo': 0.446, 'x_rna1_nll': 0.197, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.202, 'x_rna2_nll': 0.251, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.255, 'x_rna3_nll': 0.291, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.296, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.21, 'x_atac1_nll': 0.134, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.136, 'x_atac2_nll': 0.144, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.196, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.198, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.17, 'dsc_loss': 2.063, 'vae_loss': 1.7, 'gen_loss': 1.597, 'cos_loss': 0.0, 'gate_rec_loss': 17.507}, val=None, 24.8s elapsed
# [INFO] STAMOTrainer: [Epoch 50] train={'g_nll': 0.429, 'g_kl': 0.009, 'g_elbo': 0.438, 'x_rna1_nll': 0.198, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.203, 'x_rna2_nll': 0.251, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.255, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.209, 'x_atac1_nll': 0.134, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.135, 'x_atac2_nll': 0.145, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.194, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.195, 'x_atac4_nll': 0.169, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.17, 'dsc_loss': 2.064, 'vae_loss': 1.695, 'gen_loss': 1.592, 'cos_loss': 0.0, 'gate_rec_loss': 16.938}, val=None, 22.2s elapsed
# Epoch 00055: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00055: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] STAMOTrainer: [Epoch 60] train={'g_nll': 0.424, 'g_kl': 0.009, 'g_elbo': 0.432, 'x_rna1_nll': 0.196, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.201, 'x_rna2_nll': 0.25, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.254, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.21, 'x_atac1_nll': 0.134, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.135, 'x_atac2_nll': 0.145, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.194, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.195, 'x_atac4_nll': 0.167, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.168, 'dsc_loss': 2.062, 'vae_loss': 1.691, 'gen_loss': 1.588, 'cos_loss': 0.0, 'gate_rec_loss': 16.734}, val=None, 26.9s elapsed
# [INFO] STAMOTrainer: [Epoch 70] train={'g_nll': 0.423, 'g_kl': 0.009, 'g_elbo': 0.432, 'x_rna1_nll': 0.197, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.202, 'x_rna2_nll': 0.25, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.254, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.294, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.209, 'x_atac1_nll': 0.134, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.135, 'x_atac2_nll': 0.144, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.145, 'x_atac3_nll': 0.194, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.196, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.061, 'vae_loss': 1.691, 'gen_loss': 1.588, 'cos_loss': 0.0, 'gate_rec_loss': 16.686}, val=None, 26.3s elapsed
# Epoch 00076: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00076: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] STAMOTrainer: [Epoch 80] train={'g_nll': 0.423, 'g_kl': 0.009, 'g_elbo': 0.431, 'x_rna1_nll': 0.198, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.202, 'x_rna2_nll': 0.25, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.254, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.205, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.209, 'x_atac1_nll': 0.135, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.136, 'x_atac2_nll': 0.143, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.145, 'x_atac3_nll': 0.194, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.195, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.062, 'vae_loss': 1.691, 'gen_loss': 1.588, 'cos_loss': 0.0, 'gate_rec_loss': 16.644}, val=None, 26.5s elapsed
# 2025-06-28 02:21:02,793 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "65"...
# [INFO] EarlyStopping: Restoring checkpoint "65"...
# [INFO] train: FGW OT mapping from source rna1 to atac1
# How many source profiles were paired to an destination profile of the same cluster type: 0.7276326207442597
# [INFO] train: FGW OT mapping from source rna2 to atac2
# How many source profiles were paired to an destination profile of the same cluster type: 0.7917839054586382
# [INFO] train: FGW OT mapping from source rna3 to atac3
# How many source profiles were paired to an destination profile of the same cluster type: 0.8722421754746024
# [INFO] train: FGW OT mapping from source rna4 to atac4
# How many source profiles were paired to an destination profile of the same cluster type: 0.7919210897134805
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] STAMOModel: Setting `graph_batch_size` = 16276
# [INFO] STAMOModel: Setting `align_burnin` = 50
# [INFO] STAMOModel: Setting `max_epochs` = 299
# [INFO] STAMOModel: Setting `patience` = 25
# [INFO] STAMOModel: Setting `reduce_lr_patience` = 13
# [INFO] STAMOTrainer: Using training directory: "outputs/Mouse_embryo/fine-tune"
# [INFO] STAMOTrainer: [Epoch 10] train={'g_nll': 0.421, 'g_kl': 0.008, 'g_elbo': 0.429, 'x_rna1_nll': 0.196, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.201, 'x_rna2_nll': 0.249, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.253, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.204, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.208, 'x_atac1_nll': 0.134, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.135, 'x_atac2_nll': 0.143, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.144, 'x_atac3_nll': 0.195, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.196, 'x_atac4_nll': 0.167, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.057, 'vae_loss': 1.702, 'gen_loss': 1.599, 'cos_loss': 0.753, 'gate_rec_loss': 16.434}, val=None, 22.2s elapsed
# [INFO] STAMOTrainer: [Epoch 20] train={'g_nll': 0.418, 'g_kl': 0.008, 'g_elbo': 0.427, 'x_rna1_nll': 0.197, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.202, 'x_rna2_nll': 0.251, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.256, 'x_rna3_nll': 0.289, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.294, 'x_rna4_nll': 0.205, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.209, 'x_atac1_nll': 0.135, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.136, 'x_atac2_nll': 0.144, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.196, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.197, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.051, 'vae_loss': 1.709, 'gen_loss': 1.606, 'cos_loss': 0.747, 'gate_rec_loss': 16.319}, val=None, 24.1s elapsed
# [INFO] STAMOTrainer: [Epoch 30] train={'g_nll': 0.416, 'g_kl': 0.008, 'g_elbo': 0.424, 'x_rna1_nll': 0.197, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.202, 'x_rna2_nll': 0.249, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.253, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.21, 'x_atac1_nll': 0.134, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.135, 'x_atac2_nll': 0.144, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.194, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.196, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.045, 'vae_loss': 1.704, 'gen_loss': 1.602, 'cos_loss': 0.735, 'gate_rec_loss': 16.391}, val=None, 21.4s elapsed
# [INFO] STAMOTrainer: [Epoch 40] train={'g_nll': 0.414, 'g_kl': 0.008, 'g_elbo': 0.421, 'x_rna1_nll': 0.199, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.203, 'x_rna2_nll': 0.25, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.254, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.21, 'x_atac1_nll': 0.135, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.136, 'x_atac2_nll': 0.144, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.145, 'x_atac3_nll': 0.195, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.197, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.037, 'vae_loss': 1.707, 'gen_loss': 1.605, 'cos_loss': 0.734, 'gate_rec_loss': 16.535}, val=None, 22.3s elapsed
# [INFO] STAMOTrainer: [Epoch 50] train={'g_nll': 0.411, 'g_kl': 0.008, 'g_elbo': 0.419, 'x_rna1_nll': 0.198, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.202, 'x_rna2_nll': 0.251, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.255, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.004, 'x_rna4_elbo': 0.21, 'x_atac1_nll': 0.136, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.137, 'x_atac2_nll': 0.143, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.145, 'x_atac3_nll': 0.195, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.196, 'x_atac4_nll': 0.169, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.17, 'dsc_loss': 2.034, 'vae_loss': 1.708, 'gen_loss': 1.606, 'cos_loss': 0.729, 'gate_rec_loss': 16.611}, val=None, 21.8s elapsed
# [INFO] STAMOTrainer: [Epoch 60] train={'g_nll': 0.41, 'g_kl': 0.008, 'g_elbo': 0.418, 'x_rna1_nll': 0.196, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.201, 'x_rna2_nll': 0.25, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.254, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.204, 'x_rna4_kl': 0.003, 'x_rna4_elbo': 0.207, 'x_atac1_nll': 0.135, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.136, 'x_atac2_nll': 0.145, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.147, 'x_atac3_nll': 0.194, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.196, 'x_atac4_nll': 0.167, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.168, 'dsc_loss': 2.036, 'vae_loss': 1.702, 'gen_loss': 1.6, 'cos_loss': 0.729, 'gate_rec_loss': 16.659}, val=None, 22.6s elapsed
# [INFO] STAMOTrainer: [Epoch 70] train={'g_nll': 0.409, 'g_kl': 0.008, 'g_elbo': 0.416, 'x_rna1_nll': 0.197, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.202, 'x_rna2_nll': 0.25, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.254, 'x_rna3_nll': 0.291, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.003, 'x_rna4_elbo': 0.209, 'x_atac1_nll': 0.137, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.138, 'x_atac2_nll': 0.144, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.145, 'x_atac3_nll': 0.193, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.195, 'x_atac4_nll': 0.167, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.036, 'vae_loss': 1.704, 'gen_loss': 1.602, 'cos_loss': 0.725, 'gate_rec_loss': 16.62}, val=None, 21.5s elapsed
# Epoch 00070: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00070: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] STAMOTrainer: [Epoch 80] train={'g_nll': 0.408, 'g_kl': 0.008, 'g_elbo': 0.416, 'x_rna1_nll': 0.196, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.201, 'x_rna2_nll': 0.252, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.255, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.003, 'x_rna4_elbo': 0.21, 'x_atac1_nll': 0.134, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.135, 'x_atac2_nll': 0.145, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.194, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.196, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.05, 'vae_loss': 1.705, 'gen_loss': 1.603, 'cos_loss': 0.709, 'gate_rec_loss': 16.624}, val=None, 22.4s elapsed
# Epoch 00084: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00084: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] STAMOTrainer: [Epoch 90] train={'g_nll': 0.408, 'g_kl': 0.008, 'g_elbo': 0.415, 'x_rna1_nll': 0.197, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.202, 'x_rna2_nll': 0.25, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.254, 'x_rna3_nll': 0.29, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.295, 'x_rna4_nll': 0.206, 'x_rna4_kl': 0.003, 'x_rna4_elbo': 0.21, 'x_atac1_nll': 0.135, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.137, 'x_atac2_nll': 0.144, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.193, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.195, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.049, 'vae_loss': 1.704, 'gen_loss': 1.601, 'cos_loss': 0.711, 'gate_rec_loss': 16.632}, val=None, 23.0s elapsed
# [INFO] STAMOTrainer: [Epoch 100] train={'g_nll': 0.408, 'g_kl': 0.008, 'g_elbo': 0.416, 'x_rna1_nll': 0.196, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.201, 'x_rna2_nll': 0.25, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.254, 'x_rna3_nll': 0.289, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.294, 'x_rna4_nll': 0.205, 'x_rna4_kl': 0.003, 'x_rna4_elbo': 0.209, 'x_atac1_nll': 0.135, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.136, 'x_atac2_nll': 0.144, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.193, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.195, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.17, 'dsc_loss': 2.051, 'vae_loss': 1.701, 'gen_loss': 1.599, 'cos_loss': 0.718, 'gate_rec_loss': 16.635}, val=None, 22.1s elapsed
# Epoch 00107: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00107: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] STAMOTrainer: [Epoch 110] train={'g_nll': 0.408, 'g_kl': 0.008, 'g_elbo': 0.416, 'x_rna1_nll': 0.197, 'x_rna1_kl': 0.005, 'x_rna1_elbo': 0.202, 'x_rna2_nll': 0.251, 'x_rna2_kl': 0.004, 'x_rna2_elbo': 0.255, 'x_rna3_nll': 0.289, 'x_rna3_kl': 0.005, 'x_rna3_elbo': 0.293, 'x_rna4_nll': 0.205, 'x_rna4_kl': 0.003, 'x_rna4_elbo': 0.208, 'x_atac1_nll': 0.135, 'x_atac1_kl': 0.001, 'x_atac1_elbo': 0.137, 'x_atac2_nll': 0.145, 'x_atac2_kl': 0.001, 'x_atac2_elbo': 0.146, 'x_atac3_nll': 0.193, 'x_atac3_kl': 0.002, 'x_atac3_elbo': 0.195, 'x_atac4_nll': 0.168, 'x_atac4_kl': 0.001, 'x_atac4_elbo': 0.169, 'dsc_loss': 2.05, 'vae_loss': 1.703, 'gen_loss': 1.601, 'cos_loss': 0.713, 'gate_rec_loss': 16.603}, val=None, 22.1s elapsed
# 2025-06-28 03:06:03,574 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "93"...
# [INFO] EarlyStopping: Restoring checkpoint "93"...

# %%
strna_e11.obsm["X_STAMO"] = model.encode_data_minibatch("rna1", strna_e11)
strna_e13.obsm["X_STAMO"] = model.encode_data_minibatch("rna2", strna_e13)
strna_e15.obsm["X_STAMO"] = model.encode_data_minibatch("rna3", strna_e15)
strna_e18.obsm["X_STAMO"] = model.encode_data_minibatch("rna4", strna_e18)

statac_e11.obsm["X_STAMO"] = model.encode_data_minibatch("atac1", statac_e11)
statac_e13.obsm["X_STAMO"] = model.encode_data_minibatch("atac2", statac_e13)
statac_e15.obsm["X_STAMO"] = model.encode_data_minibatch("atac3", statac_e15)
statac_e18.obsm["X_STAMO"] = model.encode_data_minibatch("atac4", statac_e18)


statac = ad.concat([statac_e11, statac_e13, statac_e15, statac_e18], label="age", keys=['E11_0','E13_5', 'E15_5', 'E18_5'])
strna = ad.concat([strna_e11, strna_e13, strna_e15, strna_e18], label="age", keys=['E11_0', 'E13_5', 'E15_5', 'E18_5'])
combined = ad.concat([strna, statac], label='Batch', keys=['RNA', 'ATAC'],join='outer')
sc.pp.neighbors(combined, use_rep="X_STAMO", metric="cosine")
sc.tl.umap(combined)

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams["figure.figsize"] = (2, 2)
plt.rcParams['font.size'] = 10
plt.rcParams['legend.handletextpad'] = 0.01
fig, ax = plt.subplots(1, 3, figsize=(15, 3), gridspec_kw={'wspace': 0.9, 'hspace': 0.1})

sc.pl.umap(combined, color=["Batch"], wspace=1, show=False, ax=ax[0])
sc.pl.umap(combined, color=["age"], wspace=1, show=False, ax=ax[1])
sc.pl.umap(combined, color=['annotation'], title='annotation', show=False, ax=ax[2])   #, legend_loc=None
plt.show()

# %%
sc.tl.leiden(combined, random_state=666, key_added="leiden", resolution=0.7)

strna_e11.obs['leiden'] = combined.obs['leiden'][np.array(combined.obs['Batch'] == 'RNA') & np.array(combined.obs['age'] == 'E11_0')].values
strna_e13.obs['leiden'] = combined.obs['leiden'][np.array(combined.obs['Batch'] == 'RNA') & np.array(combined.obs['age'] == 'E13_5')].values
strna_e15.obs['leiden'] = combined.obs['leiden'][np.array(combined.obs['Batch'] == 'RNA') & np.array(combined.obs['age'] == 'E15_5')].values
strna_e18.obs['leiden'] = combined.obs['leiden'][np.array(combined.obs['Batch'] == 'RNA') & np.array(combined.obs['age'] == 'E18_5')].values

statac_e11.obs['leiden'] = combined.obs['leiden'][np.array(combined.obs['Batch'] == 'ATAC') & np.array(combined.obs['age'] == 'E11_0')].values
statac_e13.obs['leiden'] = combined.obs['leiden'][np.array(combined.obs['Batch'] == 'ATAC') & np.array(combined.obs['age'] == 'E13_5')].values
statac_e15.obs['leiden'] = combined.obs['leiden'][np.array(combined.obs['Batch'] == 'ATAC') & np.array(combined.obs['age'] == 'E15_5')].values
statac_e18.obs['leiden'] = combined.obs['leiden'][np.array(combined.obs['Batch'] == 'ATAC') & np.array(combined.obs['age'] == 'E18_5')].values

# %%
## optional refinement step for a few outlier spots
for adata in [strna_e11,strna_e13,strna_e15,strna_e18, statac_e11,statac_e13,statac_e15,statac_e18]:
    clusters = adata.obs["leiden"].values.astype(int).copy()
    adata = STAMO.utils.cluster_post_process(adata, clutser_result = clusters, key_added = "refine_cluster")
# Out:
# Post-processing for clustering result ...
# Refining clusters, run times: 1/3
# Refining clusters, run times: 2/3
# Refining clusters, run times: 3/3
#
# Post-processing for clustering result ...
# Refining clusters, run times: 1/3
# Refining clusters, run times: 2/3
# Refining clusters, run times: 3/3
#
# Post-processing for clustering result ...
# Refining clusters, run times: 1/3
# Refining clusters, run times: 2/3
# Refining clusters, run times: 3/3
#
# Post-processing for clustering result ...
# Refining clusters, run times: 1/3
# Refining clusters, run times: 2/3
# Refining clusters, run times: 3/3
#
# Post-processing for clustering result ...
# Refining clusters, run times: 1/3
# Refining clusters, run times: 2/3
# Refining clusters, run times: 3/3
#
# Post-processing for clustering result ...
# Refining clusters, run times: 1/3
# Refining clusters, run times: 2/3
# Refining clusters, run times: 3/3
#
# Post-processing for clustering result ...
# Refining clusters, run times: 1/3
# Refining clusters, run times: 2/3
# Refining clusters, run times: 3/3
#
# Post-processing for clustering result ...
# Refining clusters, run times: 1/3
# Refining clusters, run times: 2/3
# Refining clusters, run times: 3/3

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams["figure.figsize"] = (2, 2)
plt.rcParams['font.size'] = 10
plt.rcParams['legend.handletextpad'] = 0.01

spot_size = 1.1
fig, ax = plt.subplots(1, 4, figsize=(10, 3), gridspec_kw={'wspace': 0.1, 'hspace': 0.1})
sc.pl.spatial(strna_e11, color='refine_cluster', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title='E11.0_RNA', ax=ax[0], legend_loc=None)
sc.pl.spatial(strna_e13, color='refine_cluster', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title='E13.5_RNA', ax=ax[1], legend_loc=None)
sc.pl.spatial(strna_e15, color='refine_cluster', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title='E15.5_RNA', ax=ax[2], legend_loc=None)
sc.pl.spatial(strna_e18, color='refine_cluster', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title='E18.5_RNA', ax=ax[3]) #, legend_loc=None
plt.show()

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams["figure.figsize"] = (2, 2)
plt.rcParams['font.size'] = 10
spot_size = 1.1
fig, ax = plt.subplots(1, 4, figsize=(10, 3), gridspec_kw={'wspace': 0.1, 'hspace': 0.1})
sc.pl.spatial(statac_e11, color='refine_cluster', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title='E11.0_ATAC', ax=ax[0], legend_loc=None)
sc.pl.spatial(statac_e13, color='refine_cluster', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title='E13.5_ATAC', ax=ax[1], legend_loc=None)
sc.pl.spatial(statac_e15, color='refine_cluster', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title='E15.5_ATAC', ax=ax[2], legend_loc=None)
sc.pl.spatial(statac_e18, color='refine_cluster', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title='E18.5_ATAC', ax=ax[3]) #, legend_loc=None
plt.show()
