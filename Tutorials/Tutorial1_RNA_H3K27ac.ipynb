# %% [markdown]
# # Tutorial 1: Two-omics integration (RNA and H3K27ac)

# %% [markdown]
# ### This tutorial demonstrates STAMO’s ablility to integrate two unpaired P22 mouse brain slices: RNA and H3K27ac. The raw and processed data can be downloaded from GSE205055 and https://drive.google.com/drive/folders/1_V4IAxblPzNVj6P53PWjVO07lQLn2gIy?usp=sharing, respectively.

# %%
import warnings
warnings.filterwarnings('ignore')

## setting for bedtools calling in jupyter
import os
from os import path
import sys
bin_dir = path.dirname(sys.executable)
os.environ['PATH'] += os.pathsep + bin_dir
# print(os.pathsep + bin_dir)

import pandas as pd
import anndata as ad
import networkx as nx
import scanpy as sc
import STAMO
import numpy as np
import scipy.sparse as sp
from itertools import chain

STAMO.config.BEDTOOLS_PATH = "/mnt/disk4/xzhou/anaconda3/envs/STAMOv1/bin/"

# %% [markdown]
# ## Step 1: Data preprocessing

# %%
datadir = '/mnt/disk2/xzhou/code/pycharm_ATAC/STAMO_v0/data/P22/'

stH3K27ac = sc.read_h5ad(datadir+'P22_H3K27ac_cuttag.h5ad')
strna = sc.read_h5ad(datadir+'P22_H3K27ac_RNA.h5ad')

# %% [markdown]
# Raw counts are saved for the decoders which were fitted in the original feature spaces

# %%
strna.layers['counts'] = strna.X.astype(int).copy()
stH3K27ac.layers['counts'] = stH3K27ac.X.astype(int).copy()

# %% [markdown]
# ### Preprocess spRNA-seq data

# %%
sc.pp.highly_variable_genes(strna, n_top_genes=5000, flavor="seurat_v3")
strna.var['highly_variable'].sum()
# Out:
# 5000

# %%
sc.pp.normalize_total(strna) #, target_sum=1e4
sc.pp.log1p(strna)
strna = strna[:, strna.var['highly_variable']]
strna.obsm['X_feat'] = strna.X.toarray()

# %% [markdown]
# ### Preprocess spCUT&Tag-seq data

# %% [raw]
# For ATAC-seq and CUT&Tag data, we apply the latent semantic indexing (LSI) for dimension reduction. The LSI embedding will be used as input to reduce model size.

# %%
stH3K27ac.obsm['X_lsi'] = STAMO.utils.Epigenome_preprocess(stH3K27ac.copy(), key='X_lsi')

# %% [markdown]
# ### Prior feature graph construction

# %% [markdown]
# We use genomic proximity between ATAC/CUT&Tag peaks and genes as prior information.
#
# For spRNA-seq data, we extract genomic coordinates for gene names. The GTF file used here can be downloaded from [GENCODE](ftp://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_mouse/release_M25/gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz) or [here](https://drive.google.com/file/d/1sHA15AAuwieKfukjuXcTKe4UrKVunRn3/view?usp=sharing).

# %%
STAMO.data.get_gene_annotation(
    strna, gtf=datadir+"gencode.vM25.chr_patch_hapl_scaff.annotation.gtf.gz",
    gtf_by="gene_name"
)
strna.var.loc[:, ["chrom", "chromStart", "chromEnd"]].head()

strna = strna[:, ~strna.var['chrom'].isna()]

# %%
strna.var.loc[:, ["chrom", "chromStart", "chromEnd"]].head()
# Out:
#           chrom  chromStart   chromEnd
# Ppp1r14c  chr10   3366056.0  3464975.0
# Plekhg1   chr10   3740363.0  3967303.0
# Mthfd1l   chr10   3973117.0  4167081.0
# Ccdc170   chr10   4482501.0  4562231.0
# Gm10097   chr10   5069191.0  5071975.0

# %% [markdown]
# For spCUT&Tag or spATAC-seq data, we extract genomic coordinates from `var_names` in adata.

# %%
split = stH3K27ac.var_names.str.split(r"[:-]")
stH3K27ac.var["chrom"] = split.map(lambda x: x[0])
stH3K27ac.var["chromStart"] = split.map(lambda x: x[1]).astype(int)
stH3K27ac.var["chromEnd"] = split.map(lambda x: x[2]).astype(int)
stH3K27ac.var.head()
# Out:
#                      chrom  chromStart  chromEnd
# chr1-3094679-3094964  chr1     3094679   3094964
# chr1-3119499-3119936  chr1     3119499   3119936
# chr1-3121345-3121681  chr1     3121345   3121681
# chr1-3250538-3251680  chr1     3250538   3251680
# chr1-3263733-3264531  chr1     3263733   3264531

# %% [markdown]
# The genomic coordinates of the two omics features are used to construct the prior feature guidance graph. By default, an ATAC/CUT&Tag peak is connected to a gene if they overlap in either the gene body or promoter region. By setting `propagate_highly_variable = True`, highly variable genes will been propagated to the ATAC/CUT&Tag domain, by marking peaks reachable from the highly variable genes in the guidance graph. The guidance graph does not have edges within a modality, only cross-modality edges or self-loops.

# %%
guidance = STAMO.genomics.rna_anchored_guidance_graph(strna, stH3K27ac, propagate_highly_variable = True)
# Out:
# window_graph: 100%|██████████| 4527/4527 [00:00<00:00, 5806.86it/s]

# %% [markdown]
# We can verify that the obtained guidance graph complies to all of the previous standards.

# %%
STAMO.graph.check_graph(guidance, [strna, stH3K27ac])
# Out:
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] check_graph: All checks passed!

# %%
strna.var['highly_variable'].sum()
# Out:
# 4527

# %%
nx.write_graphml(guidance, datadir+"P22_two_omics_guidance_RNA_H3K27ac.graphml.gz")

strna.write(datadir+"P22_two_omics_RNA_pp.h5ad", compression="gzip")
stH3K27ac.write(datadir+"P22_two_omics_H3K27ac_pp.h5ad", compression="gzip")

# %% [markdown]
# ## Step 2: Model training

# %%
strna = ad.read_h5ad(datadir+"P22_two_omics_RNA_pp.h5ad")
stH3K27ac = ad.read_h5ad(datadir+"P22_two_omics_H3K27ac_pp.h5ad")
guidance = nx.read_graphml(datadir+"P22_two_omics_guidance_RNA_H3K27ac.graphml.gz")

strna.X = sp.csr_matrix(strna.X)
stH3K27ac.X = sp.csr_matrix(stH3K27ac.X)

strna.obs_names = strna.obs_names+'_RNA'  ### avoid same spot names between two slices
stH3K27ac.obs_names = stH3K27ac.obs_names+'_H3K27ac'

# %%
# Constructing the spatial neighbor network
STAMO.utils.Cal_Spatial_Net(strna, rad_cutoff=1.3)  # the spatial network are saved in adata.uns[‘adj’]
STAMO.utils.Cal_Spatial_Net(stH3K27ac, rad_cutoff=1.3)
# STAMO.utils.Stats_Spatial_Net(stH3K27ac)
# Out:
# ------Calculating spatial graph...
# The graph contains 37084 edges, 9370 cells.
# 3.9577 neighbors per cell on average.
# ------Calculating spatial graph...
# The graph contains 37084 edges, 9370 cells.
# 3.9577 neighbors per cell on average.

# %%
## only highly_variable features are used
guidance_hvf = guidance.subgraph(chain(
    strna.var.query("highly_variable").index,
    # scatac.var.index
    stH3K27ac.var.query("highly_variable").index
)).copy()
vertices = sorted(guidance_hvf.nodes)

# %% [markdown]
# #### Dataset configure

# %% [markdown]
# Before model training, we need to configure the datasets using STAMO.models.configure_dataset. For each dataset to be integrated, we need to specify a probabilistic generative model. Here we model the raw counts of both spRNA-seq and spATAC-seq/spCUT&Tag-seq using the negative binomial distribution ("NB").
#
# Optionally, we can specify whether only the highly variable features should be used (use_highly_variable), what data layer to use (use_layer), as well as what preprocessing embedding (use_rep) to use as first encoder transformation "use_obs_names=True" is used to construct cross-omics anchors identified by optimal transport.

# %%
STAMO.models.configure_dataset(strna, "NB", use_highly_variable=True, use_rep="X_feat", use_layer="counts",  use_obs_names=True)
STAMO.models.configure_dataset(stH3K27ac, "NB", use_highly_variable=True, use_rep="X_lsi", use_layer="counts", use_obs_names=True)

# %%
model = STAMO.models.train(
    {"RNA": strna, "H3K27ac": stH3K27ac}, guidance_hvf,
    fit_kws={"directory": "outputs/P22_H3K27ac"}, OT_pair=[('RNA','H3K27ac')]    ### compile_kws={"lam_align": 0.05}
)
# Out:
# [INFO] autodevice: Using GPU 2 as computation device.
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] STAMOModel: Setting `graph_batch_size` = 24121
# [INFO] STAMOModel: Setting `max_epochs` = 183
# [INFO] STAMOModel: Setting `patience` = 16
# [INFO] STAMOModel: Setting `reduce_lr_patience` = 8
# [INFO] STAMOTrainer: Using training directory: "outputs/P22_H3K27ac/pretrain"
# [INFO] STAMOTrainer: [Epoch 10] train={'g_nll': 0.454, 'g_kl': 0.006, 'g_elbo': 0.459, 'x_RNA_nll': 0.269, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.273, 'x_H3K27ac_nll': 0.092, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.093, 'dsc_loss': 0.69, 'vae_loss': 0.39, 'gen_loss': 0.355, 'cos_loss': 0.0, 'gate_rec_loss': 5.244}, val=None, 11.0s elapsed
# [INFO] STAMOTrainer: [Epoch 20] train={'g_nll': 0.422, 'g_kl': 0.005, 'g_elbo': 0.428, 'x_RNA_nll': 0.264, 'x_RNA_kl': 0.003, 'x_RNA_elbo': 0.267, 'x_H3K27ac_nll': 0.092, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.093, 'dsc_loss': 0.692, 'vae_loss': 0.381, 'gen_loss': 0.346, 'cos_loss': 0.0, 'gate_rec_loss': 3.986}, val=None, 11.1s elapsed
# [INFO] STAMOTrainer: [Epoch 30] train={'g_nll': 0.407, 'g_kl': 0.005, 'g_elbo': 0.412, 'x_RNA_nll': 0.261, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.264, 'x_H3K27ac_nll': 0.092, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.093, 'dsc_loss': 0.693, 'vae_loss': 0.377, 'gen_loss': 0.343, 'cos_loss': 0.0, 'gate_rec_loss': 3.713}, val=None, 11.3s elapsed
# [INFO] STAMOTrainer: [Epoch 40] train={'g_nll': 0.4, 'g_kl': 0.005, 'g_elbo': 0.406, 'x_RNA_nll': 0.261, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.264, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.693, 'vae_loss': 0.376, 'gen_loss': 0.341, 'cos_loss': 0.0, 'gate_rec_loss': 3.615}, val=None, 11.9s elapsed
# [INFO] STAMOTrainer: [Epoch 50] train={'g_nll': 0.398, 'g_kl': 0.005, 'g_elbo': 0.403, 'x_RNA_nll': 0.261, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.265, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.693, 'vae_loss': 0.376, 'gen_loss': 0.342, 'cos_loss': 0.0, 'gate_rec_loss': 3.514}, val=None, 11.7s elapsed
# [INFO] STAMOTrainer: [Epoch 60] train={'g_nll': 0.396, 'g_kl': 0.005, 'g_elbo': 0.402, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.264, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.693, 'vae_loss': 0.375, 'gen_loss': 0.34, 'cos_loss': 0.0, 'gate_rec_loss': 3.494}, val=None, 11.0s elapsed
# Epoch 00060: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00060: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] STAMOTrainer: [Epoch 70] train={'g_nll': 0.395, 'g_kl': 0.005, 'g_elbo': 0.401, 'x_RNA_nll': 0.259, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.263, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.693, 'vae_loss': 0.375, 'gen_loss': 0.34, 'cos_loss': 0.0, 'gate_rec_loss': 3.523}, val=None, 11.0s elapsed
# Epoch 00072: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00072: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# 2025-07-01 00:41:23,630 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "63"...
# [INFO] EarlyStopping: Restoring checkpoint "63"...
# [INFO] train: FGW OT mapping from source RNA to H3K27ac
# [INFO] train: downsample source data to 5000...
# [INFO] train: downsample target data to 5000...
# How many source profiles were paired to an destination profile of the same cluster type: 0.9346
# [INFO] check_graph: Checking variable coverage...
# [INFO] check_graph: Checking edge attributes...
# [INFO] check_graph: Checking self-loops...
# [INFO] check_graph: Checking graph symmetry...
# [INFO] STAMOModel: Setting `graph_batch_size` = 24121
# [INFO] STAMOModel: Setting `align_burnin` = 34
# [INFO] STAMOModel: Setting `max_epochs` = 200
# [INFO] STAMOModel: Setting `patience` = 17
# [INFO] STAMOModel: Setting `reduce_lr_patience` = 9
# [INFO] STAMOTrainer: Using training directory: "outputs/P22_H3K27ac/fine-tune"
# [INFO] STAMOTrainer: [Epoch 10] train={'g_nll': 0.395, 'g_kl': 0.005, 'g_elbo': 0.4, 'x_RNA_nll': 0.261, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.265, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.693, 'vae_loss': 0.378, 'gen_loss': 0.343, 'cos_loss': 0.075, 'gate_rec_loss': 3.461}, val=None, 10.0s elapsed
# [INFO] STAMOTrainer: [Epoch 20] train={'g_nll': 0.395, 'g_kl': 0.005, 'g_elbo': 0.401, 'x_RNA_nll': 0.261, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.264, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.692, 'vae_loss': 0.377, 'gen_loss': 0.342, 'cos_loss': 0.072, 'gate_rec_loss': 3.416}, val=None, 10.1s elapsed
# [INFO] STAMOTrainer: [Epoch 30] train={'g_nll': 0.395, 'g_kl': 0.005, 'g_elbo': 0.4, 'x_RNA_nll': 0.261, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.264, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.69, 'vae_loss': 0.377, 'gen_loss': 0.342, 'cos_loss': 0.071, 'gate_rec_loss': 3.408}, val=None, 10.6s elapsed
# [INFO] STAMOTrainer: [Epoch 40] train={'g_nll': 0.395, 'g_kl': 0.005, 'g_elbo': 0.4, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.264, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.69, 'vae_loss': 0.376, 'gen_loss': 0.342, 'cos_loss': 0.07, 'gate_rec_loss': 3.374}, val=None, 10.4s elapsed
# Epoch 00049: reducing learning rate of group 0 to 2.0000e-04.
# Epoch 00049: reducing learning rate of group 0 to 2.0000e-04.
# [INFO] LRScheduler: Learning rate reduction: step 1
# [INFO] STAMOTrainer: [Epoch 50] train={'g_nll': 0.394, 'g_kl': 0.005, 'g_elbo': 0.399, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.004, 'x_RNA_elbo': 0.264, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.692, 'vae_loss': 0.376, 'gen_loss': 0.342, 'cos_loss': 0.068, 'gate_rec_loss': 3.392}, val=None, 10.4s elapsed
# Epoch 00059: reducing learning rate of group 0 to 2.0000e-05.
# Epoch 00059: reducing learning rate of group 0 to 2.0000e-05.
# [INFO] LRScheduler: Learning rate reduction: step 2
# [INFO] STAMOTrainer: [Epoch 60] train={'g_nll': 0.393, 'g_kl': 0.005, 'g_elbo': 0.399, 'x_RNA_nll': 0.259, 'x_RNA_kl': 0.003, 'x_RNA_elbo': 0.263, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.692, 'vae_loss': 0.376, 'gen_loss': 0.341, 'cos_loss': 0.067, 'gate_rec_loss': 3.452}, val=None, 10.5s elapsed
# [INFO] STAMOTrainer: [Epoch 70] train={'g_nll': 0.394, 'g_kl': 0.005, 'g_elbo': 0.399, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.003, 'x_RNA_elbo': 0.264, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.692, 'vae_loss': 0.377, 'gen_loss': 0.342, 'cos_loss': 0.067, 'gate_rec_loss': 3.451}, val=None, 10.4s elapsed
# Epoch 00077: reducing learning rate of group 0 to 2.0000e-06.
# Epoch 00077: reducing learning rate of group 0 to 2.0000e-06.
# [INFO] LRScheduler: Learning rate reduction: step 3
# [INFO] STAMOTrainer: [Epoch 80] train={'g_nll': 0.394, 'g_kl': 0.005, 'g_elbo': 0.399, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.003, 'x_RNA_elbo': 0.263, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.692, 'vae_loss': 0.376, 'gen_loss': 0.342, 'cos_loss': 0.067, 'gate_rec_loss': 3.442}, val=None, 10.6s elapsed
# Epoch 00089: reducing learning rate of group 0 to 2.0000e-07.
# Epoch 00089: reducing learning rate of group 0 to 2.0000e-07.
# [INFO] LRScheduler: Learning rate reduction: step 4
# [INFO] STAMOTrainer: [Epoch 90] train={'g_nll': 0.394, 'g_kl': 0.005, 'g_elbo': 0.399, 'x_RNA_nll': 0.26, 'x_RNA_kl': 0.003, 'x_RNA_elbo': 0.263, 'x_H3K27ac_nll': 0.091, 'x_H3K27ac_kl': 0.001, 'x_H3K27ac_elbo': 0.092, 'dsc_loss': 0.692, 'vae_loss': 0.376, 'gen_loss': 0.341, 'cos_loss': 0.067, 'gate_rec_loss': 3.444}, val=None, 11.9s elapsed
# 2025-07-01 01:00:06,863 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# [INFO] EarlyStopping: Restoring checkpoint "79"...
# [INFO] EarlyStopping: Restoring checkpoint "79"...

# %% [markdown]
# ## UMAP visualization and Clustering

# %%
strna.obsm["X_STAMO"] = model.encode_data_minibatch("RNA", strna)
stH3K27ac.obsm["X_STAMO"] = model.encode_data_minibatch("H3K27ac", stH3K27ac)

# %%
combined = ad.concat([strna, stH3K27ac], label='Batch', keys=['RNA','H3K27ac'],join='outer')
sc.pp.neighbors(combined, use_rep="X_STAMO", metric="cosine")
sc.tl.umap(combined)

import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams["figure.figsize"] = (2, 2)
plt.rcParams['font.size'] = 10
plt.rcParams['legend.handletextpad'] = 0.01
fig, ax = plt.subplots(1, 3, figsize=(15, 3), gridspec_kw={'wspace': 0.9, 'hspace': 0.1})

sc.pl.umap(combined, color=["Batch"], wspace=1, legend_fontsize=10, show=False, ax=ax[0])
sc.pl.umap(combined, color=['annotation'], legend_fontsize=10, show=False, ax=ax[1])   #, legend_loc=None
sc.pl.umap(combined, color=['annotation'], legend_fontsize=10, show=False, ax=ax[2], legend_loc='on data')
plt.show()

# %%
sc.tl.leiden(combined, random_state=666, key_added="leiden", resolution=1.3) 

strna.obs['leiden'] = combined.obs['leiden'][combined.obs['Batch']=='RNA'].values
stH3K27ac.obs['leiden'] = combined.obs['leiden'][combined.obs['Batch']=='H3K27ac'].values

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams["figure.figsize"] = (3, 3)
plt.rcParams['font.size'] = 10
plt.rcParams['legend.handletextpad'] = 0.01
# plt.rcParams['legend.labelspacing'] = 0.1 

spot_size = 30
fig, ax = plt.subplots(1, 2, figsize=(10, 3), gridspec_kw={'wspace': 0.2, 'hspace': 0.1})

spot_size = 1.1 
sc.pl.spatial(strna, color='leiden', cmap="viridis", show=False, frameon=False, spot_size=spot_size, title=['RNA'], ax=ax[0])
sc.pl.spatial(stH3K27ac, color='leiden', cmap="viridis", show=False, frameon=False, spot_size=spot_size,title=['H3K27ac'], ax=ax[1])
plt.show()

# %% [markdown]
# ## Cross-omics generation: From spCUT&Tag-seq to spRNA-seq data

# %%
strna.X = strna.layers['counts']

generate_rna = STAMO.utils.cross_predict(stH3K27ac, strna, model, guidance=guidance_hvf, OT_pair=("H3K27ac", "RNA"))

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = "Arial"
plt.rcParams["figure.figsize"] = (3, 3)
plt.rcParams['font.size'] = 10
markers = ['Tspan2']
sc.pl.spatial(generate_rna, color=markers,       
              img_key=None, show=True, frameon=False, spot_size=1,  # cmap='magma',
              bw=False, colorbar_loc=None, ncols=6,wspace=0, vmax='p99', vmin='p10')
